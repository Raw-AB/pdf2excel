# %%
import tabula
pdf = tabula.read_pdf('test.pdf', pages = 65)
# Out:
# Got stderr: Jun 09, 2022 4:33:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_111
# Jun 09, 2022 4:33:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Jun 09, 2022 4:33:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Jun 09, 2022 4:33:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Jun 09, 2022 4:33:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Jun 09, 2022 4:33:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
import numpy as np
array= np.reshape(pdf, (30, 8))

# %%
import pandas as pd
df=pd.DataFrame(array)

# %%
df.to_excel('out.xls')

# %%
df
# Out:
#               0            1    2                                3  \
# 0           NaN          NaN  NaN                       الالتزامات
# 1           NaN          NaN  NaN        الالتزامات غير المتداولة:
# 2     8.637.605    7.846.606   26                 قروض طويلة الأجل
# 3     5.239.313    5.466.916   27         مخصص مكافأة نهاية الخدمة
# 4     2.237.853    2.353.593   28            التزامات عقود الإيجار
# 5       725.625      550.741   29                           مخصصات
# 6       771.915      771.915   30                   التزامات العقد
# 7     6.201.591    5.843.115   31            التزامات مالية وأخُرى
# 8    23.813.902   22.832.886  NaN  إجمالي الالتزامات غير المتداولة
# 9           NaN          NaN  NaN            الالتزامات المتداولة:
# 10   19.711.207   17.114.298   32            دائنون تجاريون وآخرون
# 11    4.158.923    3.647.727   29                           مخصصات
# 12    1.901.237    3.591.950   30                   التزامات العقد
# ...
